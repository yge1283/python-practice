# %%
import pandas as pd

# %%
pd.Series(['banana',42])
# Out:
# 0    banana
# 1        42
# dtype: object

# %%
df=pd.DataFrame({
    "name":['홍길동','김철수'],
    "age":[24,34]
},index=["A","B"])


print(df)
# Out:
#   name  age
# A  홍길동   24
# B  김철수   34

# %%
df.T
# 행렬 전환
# Out:
#         A    B
# name  홍길동  김철수
# age    24   34

# %%
dff=pd.read_csv('data/scientists.csv')

# %%
dff.describe()
# Out:
#              Age
# count   8.000000
# mean   59.125000
# std    18.325918
# min    37.000000
# 25%    44.000000
# 50%    58.500000
# 75%    68.750000
# max    90.000000

# %%
dff.head()
# Out:
#                    Name        Born        Died  Age    Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37       Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61  Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90         Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66       Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56     Biologist

# %%
dff.info
# Out:
# <bound method DataFrame.info of                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician>

# %%
print(dff.mean(numeric_only=True))
# Out:
# Age    59.125
# dtype: float64

# %%
print(dff.mean(axis=1,numeric_only=True))
# Out:
# 0    37.0
# 1    61.0
# 2    90.0
# 3    66.0
# 4    56.0
# 5    45.0
# 6    41.0
# 7    77.0
# dtype: float64

# %%
dff.Age
# Out:
# 0    37
# 1    61
# 2    90
# 3    66
# 4    56
# 5    45
# 6    41
# 7    77
# Name: Age, dtype: int64

# %%
dff
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
dff[dff.Age>dff.Age.mean()]
# Out:
#                    Name        Born        Died  Age     Occupation
# 1        William Gosset  1876-06-13  1937-10-16   61   Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90          Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66        Chemist
# 7          Johann Gauss  1777-04-30  1855-02-23   77  Mathematician

# %%
dff
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
dff.Age, dff.Age+pd.Series([10,20])
dff.Age, dff.Age+10
# 브로드캐스팅
# Out:
# (0    37
#  1    61
#  2    90
#  3    66
#  4    56
#  5    45
#  6    41
#  7    77
#  Name: Age, dtype: int64,
#  0     47
#  1     71
#  2    100
#  3     76
#  4     66
#  5     55
#  6     51
#  7     87
#  Name: Age, dtype: int64)

# %%
dff.sort_index(ascending=False)
# Out:
#                    Name        Born        Died  Age          Occupation
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist

# %%
dff_sort=dff.sort_values('Age')

# %%
dff_sort
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse

# %%
dff.Age,dff_sort.Age+dff.Age
# Out:
# (0    37
#  1    61
#  2    90
#  3    66
#  4    56
#  5    45
#  6    41
#  7    77
#  Name: Age, dtype: int64,
#  0     74
#  1    122
#  2    180
#  3    132
#  4    112
#  5     90
#  6     82
#  7    154
#  Name: Age, dtype: int64)

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        8 non-null      object
#  1   Born        8 non-null      object
#  2   Died        8 non-null      object
#  3   Age         8 non-null      int64
#  4   Occupation  8 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 452.0+ bytes

# %%
pd.to_datetime(dff.Born)
# Out:
# 0   1920-07-25
# 1   1876-06-13
# 2   1820-05-12
# 3   1867-11-07
# 4   1907-05-27
# 5   1813-03-15
# 6   1912-06-23
# 7   1777-04-30
# Name: Born, dtype: datetime64[ns]

# %%
date='09-12-14'
pd.to_datetime(date,format='%m-%d-%y')
# Out:
# Timestamp('2014-09-12 00:00:00')

# %%
dff['born_dt']=pd.to_datetime(dff.Born)

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        8 non-null      object
#  1   Born        8 non-null      object
#  2   Died        8 non-null      object
#  3   Age         8 non-null      int64
#  4   Occupation  8 non-null      object
#  5   born_dt     8 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 516.0+ bytes

# %%
dff.head()
# Out:
#                    Name        Born        Died  Age    Occupation    born_dt
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37       Chemist 1920-07-25
# 1        William Gosset  1876-06-13  1937-10-16   61  Statistician 1876-06-13
# 2  Florence Nightingale  1820-05-12  1910-08-13   90         Nurse 1820-05-12
# 3           Marie Curie  1867-11-07  1934-07-04   66       Chemist 1867-11-07
# 4         Rachel Carson  1907-05-27  1964-04-14   56     Biologist 1907-05-27

# %%
## 다음 회차

# %%
import pandas ad pd

# %%
pd.read_csv('data/pew.csv')
# Out:
#                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  \
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4        Don’t know/refused     15       14       15       11       10
# 5          Evangelical Prot    575      869     1064      982      881
# 6                     Hindu      1        9        7        9       11
# 7   Historically Black Prot    228      244      236      238      197
# 8         Jehovah's Witness     20       27       24       24       21
# 9                    Jewish     19       19       25       25       30
# 10            Mainline Prot    289      495      619      655      651
# 11                   Mormon     29       40       48       51       56
# ...

# %%
pew_df=pd.read_csv('data/pew.csv')

# %%
pew_df.melt()
# Out:
# <bound method DataFrame.melt of                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  \
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4        Don’t know/refused     15       14       15       11       10
# 5          Evangelical Prot    575      869     1064      982      881
# 6                     Hindu      1        9        7        9       11
# 7   Historically Black Prot    228      244      236      238      197
# 8         Jehovah's Witness     20       27       24       24       21
# 9                    Jewish     19       19       25       25       30
# 10            Mainline Prot    289      495      619      655      651
# 11                   Mormon     29       40       48       51       56
# ...

# %%
pew_df.head(1)
# Out:
#    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  $50-75k  $75-100k  \
# 0  Agnostic     27       34       60       81       76      137       122
#
#    $100-150k  >150k  Don't know/refused
# 0        109     84                  96

# %%
pew_df.melt(id_vars=['religion'], var_name="income" ,value_name="count")
# Out:
#                   religion              income  count
# 0                 Agnostic               <$10k     27
# 1                  Atheist               <$10k     12
# 2                 Buddhist               <$10k     27
# 3                 Catholic               <$10k    418
# 4       Don’t know/refused               <$10k     15
# ..                     ...                 ...    ...
# 175               Orthodox  Don't know/refused     73
# 176        Other Christian  Don't know/refused     18
# 177           Other Faiths  Don't know/refused     71
# 178  Other World Religions  Don't know/refused      8
# 179           Unaffiliated  Don't know/refused    597
#
# [180 rows x 3 columns]

# %%
cardf=pd.read_csv('data/인천광역시_소방장비현황_20201231.csv',encoding='cp949')

# %%
car_df_melt=cardf.melt(id_vars='소방서별(1)')

# %%
car_df_melt.columns
# Out:
# Index(['소방서별(1)', 'variable', 'value'], dtype='object')

# %%
car_df_melt.rename(columns={"소방서별(1)": "소방서명", "variable": "차량종류"},inplace=True)

# %%
car_df_melt.columns=['소방서명','차량종류','차량대수']

# %%
car_df_melt.columns
# Out:
# Index(['소방서명', '차량종류', '차량대수'], dtype='object')

# %%
bi=pd.read_csv('data/billboard.csv')

# %%
bi.columns
# Out:
# Index(['year', 'artist', 'track', 'time', 'date.entered', 'wk1', 'wk2', 'wk3',
#        'wk4', 'wk5', 'wk6', 'wk7', 'wk8', 'wk9', 'wk10', 'wk11', 'wk12',
#        'wk13', 'wk14', 'wk15', 'wk16', 'wk17', 'wk18', 'wk19', 'wk20', 'wk21',
#        'wk22', 'wk23', 'wk24', 'wk25', 'wk26', 'wk27', 'wk28', 'wk29', 'wk30',
#        'wk31', 'wk32', 'wk33', 'wk34', 'wk35', 'wk36', 'wk37', 'wk38', 'wk39',
#        'wk40', 'wk41', 'wk42', 'wk43', 'wk44', 'wk45', 'wk46', 'wk47', 'wk48',
#        'wk49', 'wk50', 'wk51', 'wk52', 'wk53', 'wk54', 'wk55', 'wk56', 'wk57',
#        'wk58', 'wk59', 'wk60', 'wk61', 'wk62', 'wk63', 'wk64', 'wk65', 'wk66',
#        'wk67', 'wk68', 'wk69', 'wk70', 'wk71', 'wk72', 'wk73', 'wk74', 'wk75',
#        'wk76'],
#       dtype='object')

# %%
bi_melt=bi.melt(id_vars=['year', 'artist', 'track', 'time', 'date.entered'])

# %%
bi_melt.columns=['year', 'artist', 'track', 'time', 'date.entered','week','rating']

# %%
bi_melt
# Out:
#        year            artist                    track  time date.entered  \
# 0      2000             2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26
# 1      2000           2Ge+her  The Hardest Part Of ...  3:15   2000-09-02
# 2      2000      3 Doors Down               Kryptonite  3:53   2000-04-08
# 3      2000      3 Doors Down                    Loser  4:24   2000-10-21
# 4      2000          504 Boyz            Wobble Wobble  3:35   2000-04-15
# ...     ...               ...                      ...   ...          ...
# 24087  2000       Yankee Grey     Another Nine Minutes  3:10   2000-04-29
# 24088  2000  Yearwood, Trisha          Real Live Woman  3:55   2000-04-01
# 24089  2000   Ying Yang Twins  Whistle While You Tw...  4:19   2000-03-18
# 24090  2000     Zombie Nation            Kernkraft 400  3:30   2000-09-02
# 24091  2000   matchbox twenty                     Bent  4:12   2000-04-29
#
#        week  rating
# 0       wk1    87.0
# 1       wk1    91.0
# ...
